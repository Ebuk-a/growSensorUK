# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
# import fiona
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.9.1dev-CAPI-1.14.1) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
grow_df = pd.read_csv('resources/GrowLocations.csv')

# %%
grow_df
# Out:
#                    Serial  Latitude  Longitude  \
# 0      PI040298AD5J215142    -7.923     54.980
# 1      PI040298AD5J215142    -7.923     54.980
# 2      PI040298AD5J215142    -7.923     54.980
# 3      PI040298AD5J215142    -7.923     54.980
# 4      PI040298AD5J215142    -7.923     54.980
# ...                   ...       ...        ...
# 39289  PI040298AA4E057627   -17.895     27.825
# 39290  PI040298AA4E057627   -17.895     27.825
# 39291  PI040298AA4E057627   -17.895     27.825
# 39292  PI040298AA4E057627   -17.895     27.825
# 39293  PI040298AA4E057627   -17.895     27.825
#
#                                                   Type    SensorType  \
# 0       Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 1         Thingful.Connectors.GROWSensors.BatteryLevel  Flower Power
# 2      Thingful.Connectors.GROWSensors.FertilizerLevel  Flower Power
# 3                Thingful.Connectors.GROWSensors.Light  Flower Power
# 4         Thingful.Connectors.GROWSensors.SoilMoisture  Flower Power
# ...                                                ...           ...
# 39289     Thingful.Connectors.GROWSensors.BatteryLevel  Flower Power
# 39290  Thingful.Connectors.GROWSensors.FertilizerLevel  Flower Power
# 39291            Thingful.Connectors.GROWSensors.Light  Flower Power
# 39292     Thingful.Connectors.GROWSensors.SoilMoisture  Flower Power
# 39293   Thingful.Connectors.GROWSensors.WaterTankLevel  Flower Power
#
#                                  Code                 BeginTime  \
# 0      Grow.Thingful.Sensors_5tjrqt1c  2018-10-17T13:14:07.000Z
# 1      Grow.Thingful.Sensors_5tjrqt1c  2018-10-17T13:14:07.000Z
# 2      Grow.Thingful.Sensors_5tjrqt1c  2018-10-17T13:14:07.000Z
# 3      Grow.Thingful.Sensors_5tjrqt1c  2018-10-17T13:14:07.000Z
# 4      Grow.Thingful.Sensors_5tjrqt1c  2018-10-17T13:14:07.000Z
# ...                               ...                       ...
# 39289  Grow.Thingful.Sensors_v5g5zde1  2019-10-19T14:48:29.000Z
# 39290  Grow.Thingful.Sensors_v5g5zde1  2019-10-19T14:48:29.000Z
# 39291  Grow.Thingful.Sensors_v5g5zde1  2019-10-19T14:48:29.000Z
# 39292  Grow.Thingful.Sensors_v5g5zde1  2019-10-19T14:48:29.000Z
# 39293  Grow.Thingful.Sensors_v5g5zde1  2019-10-19T14:48:29.000Z
#
#                         EndTime
# 0      2018-10-17T13:59:07.000Z
# 1      2018-10-17T13:59:07.000Z
# 2      2018-10-17T13:59:07.000Z
# 3      2018-10-17T13:59:07.000Z
# 4      2018-10-17T13:59:07.000Z
# ...                         ...
# 39289  2019-10-30T15:33:29.000Z
# 39290  2019-10-30T15:33:29.000Z
# 39291  2019-10-30T15:33:29.000Z
# 39292  2019-10-30T15:33:29.000Z
# 39293  2019-10-30T15:33:29.000Z
#
# [39294 rows x 8 columns]

# %%
filtered_grow_df = grow_df[(grow_df['Latitude'] >= 50.681) & (grow_df['Latitude'] <= 57.985) 
                        & (grow_df['Longitude'] >= -10.592) & (grow_df['Longitude'] <= 1.6848)]

filtered_grow_df
# Out:
#                                                   Serial  Latitude  Longitude  \
# 22026                                 PI040298AD5I214048    54.443     -1.934
# 22027                                 PI040298AD5I214048    54.443     -1.934
# 22028                                 PI040298AD5I214048    54.443     -1.934
# 22029                                 PI040298AD5I214048    54.443     -1.934
# 22030                                 PI040298AD5I214048    54.443     -1.934
# ...                                                  ...       ...        ...
# 22465  PI040298AD5G204372. FuturePractice:,Id:795,Lan...    53.444     -1.934
# 22466  PI040298AD5G204372. FuturePractice:,Id:795,Lan...    53.444     -1.934
# 22467  PI040298AD5G204372. FuturePractice:,Id:795,Lan...    53.444     -1.934
# 22468  PI040298AD5G204372. FuturePractice:,Id:795,Lan...    53.444     -1.934
# 22469  PI040298AD5G204372. FuturePractice:,Id:795,Lan...    53.444     -1.934
#
#                                                   Type    SensorType  \
# 22026   Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 22027     Thingful.Connectors.GROWSensors.BatteryLevel  Flower Power
# 22028  Thingful.Connectors.GROWSensors.FertilizerLevel  Flower Power
# 22029            Thingful.Connectors.GROWSensors.Light  Flower Power
# 22030     Thingful.Connectors.GROWSensors.SoilMoisture  Flower Power
# ...                                                ...           ...
# 22465     Thingful.Connectors.GROWSensors.BatteryLevel  Flower Power
# 22466  Thingful.Connectors.GROWSensors.FertilizerLevel  Flower Power
# 22467            Thingful.Connectors.GROWSensors.Light  Flower Power
# 22468     Thingful.Connectors.GROWSensors.SoilMoisture  Flower Power
# 22469   Thingful.Connectors.GROWSensors.WaterTankLevel  Flower Power
#
#                                  Code                 BeginTime  \
# 22026  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# 22027  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# 22028  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# 22029  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# 22030  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# ...                               ...                       ...
# 22465  Grow.Thingful.Sensors_g82a07b3  2019-05-23T15:21:53.000Z
# 22466  Grow.Thingful.Sensors_g82a07b3  2019-05-23T15:21:53.000Z
# 22467  Grow.Thingful.Sensors_g82a07b3  2019-05-23T15:21:53.000Z
# 22468  Grow.Thingful.Sensors_g82a07b3  2019-05-23T15:21:53.000Z
# 22469  Grow.Thingful.Sensors_g82a07b3  2019-05-23T15:21:53.000Z
#
#                         EndTime
# 22026  2019-10-23T17:18:06.000Z
# 22027  2019-10-23T17:18:06.000Z
# 22028  2019-10-23T17:18:06.000Z
# 22029  2019-10-23T17:18:06.000Z
# 22030  2019-10-23T17:18:06.000Z
# ...                         ...
# 22465  2019-10-23T17:14:56.000Z
# 22466  2019-10-23T17:14:56.000Z
# 22467  2019-10-23T17:14:56.000Z
# 22468  2019-10-23T17:14:56.000Z
# 22469  2019-10-23T17:14:56.000Z
#
# [120 rows x 8 columns]

# %%
geometry = [Point(xy) for xy in zip(filtered_grow_df['Longitude'], filtered_grow_df['Latitude'])]
gdf = GeoDataFrame(filtered_grow_df, geometry=geometry)

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=1)
# Out:
# <AxesSubplot:>

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world[world.continent == 'Europe'].plot(figsize=(10, 6)), marker='o', color='red', markersize=15)
# Out:
# <AxesSubplot:>

# %%
# df = pd.read_csv("Long_Lats.csv", delimiter=',', skiprows=0, low_memory=False)

# geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
# gdf = GeoDataFrame(df, geometry=geometry)   

# #this is a simple map that goes with geopandas
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15)

# %%
# gdf = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"), where="continent='Europe'",
# )
# gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15)

# Causing errors

# %% [markdown]
# ### James

# %%
uk = gpd.read_file("uk_regions.geojson")
uk.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
gdf.plot(ax=uk.plot(figsize=(20, 20)), marker='o', color='red', markersize=3)
# Out:
# <AxesSubplot:>

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ee62355c84d4e64a8096efb573646f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ee62355c84d4e64a8096efb573646f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ee62355c84d4e64a8096efb573646f4 = L.map(
#                 &quot;map_9ee62355c84d4e64a8096efb573646f4&quot;,
#                 {
#                     center: [53.943, -1.935],
#                     crs: L.CRS.Simple,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9ee62355c84d4e64a8096efb573646f4);
#
#
#
#
#
#             map_9ee62355c84d4e64a8096efb573646f4.fitBounds(
#                 [[53.443, -1.937], [54.443, -1.933]],
#                 {}
#             );
#
#
#         function geo_json_440853bfe3fb11cc1da9ff834c4d96be_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_440853bfe3fb11cc1da9ff834c4d96be_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_440853bfe3fb11cc1da9ff834c4d96be_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_440853bfe3fb11cc1da9ff834c4d96be_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_440853bfe3fb11cc1da9ff834c4d96be_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_440853bfe3fb11cc1da9ff834c4d96be.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_440853bfe3fb11cc1da9ff834c4d96be_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_440853bfe3fb11cc1da9ff834c4d96be = L.geoJson(null, {
#                 onEachFeature: geo_json_440853bfe3fb11cc1da9ff834c4d96be_onEachFeature,
#
#                 style: geo_json_440853bfe3fb11cc1da9ff834c4d96be_styler,
#                 pointToLayer: geo_json_440853bfe3fb11cc1da9ff834c4d96be_pointToLayer
#         });
#
#         function geo_json_440853bfe3fb11cc1da9ff834c4d96be_add (data) {
#             geo_json_440853bfe3fb11cc1da9ff834c4d96be
#                 .addData(data)
#                 .addTo(map_9ee62355c84d4e64a8096efb573646f4);
#         }
#             geo_json_440853bfe3fb11cc1da9ff834c4d96be_add({&quot;bbox&quot;: [-1.937, 53.443, -1.933, 54.443], &quot;features&quot;: [{&quot;bbox&quot;: [-1.934, 54.443, -1.934, 54.443], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.934, 54.443], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;22026&quot;, &quot;properties&quot;: {&quot;BeginTime&quot;: &quot;2019-05-23T16:11:17.000Z&quot;, &quot;Code&quot;: &quot;Grow.Thingful.Sensors_98b4dscx&quot;, &quot;EndTime&quot;: &quot;2019-10-23T17:18:06.000Z&quot;, &quot;Latitude&quot;: 54.443, &quot;Longitude&quot;: -1.934, &quot;SensorType&quot;: &quot;Flower Power&quot;, &quot;Serial&quot;: &quot;PI040298AD5I214048&quot;, &quot;Type&quot;: &quot;Thingful.Connectors.GROWSensors.AirTemperature&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-1.934, 54.443, -1.934, 54.443], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.934, 54.443], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;22027&quot;, &quot;properties&quot;: {&quot;BeginTime&quot;: &quot;2019-05-23T16:11:17.000Z&quot;, &quot;Code&quot;: &quot;Grow.Thingful.Sensors_98b4dscx&quot;, &quot;EndTime&quot;: &quot;2019-10-23T17:18:06.000Z&quot;, &quot;Latitude&quot;: 54.443, &quot;Longitude&quot;: -1.934, &quot;SensorType&quot;: &quot;Flower Power&quot;, &quot;Serial&quot;: &quot;PI040298AD5I214048&quot;, &quot;Type&quot;: &quot;Thingful.Connectors.GROWSensors.BatteryLevel&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-1.934, 54.443, -1.934, 54

# %% [markdown]
# ### Check unique longitude and latitude values

# %%
gdf.drop_duplicates('Longitude')
# Out:
#                    Serial  Latitude  Longitude  \
# 22026  PI040298AD5I214048    54.443     -1.934
# 22038  PI040298AD5J214359    53.444     -1.937
# 22362  PI040298AA4E057880    53.449     -1.933
#
#                                                  Type    SensorType  \
# 22026  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 22038  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 22362  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
#
#                                  Code                 BeginTime  \
# 22026  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# 22038  Grow.Thingful.Sensors_txegxh37  2019-05-23T15:10:46.000Z
# 22362  Grow.Thingful.Sensors_dwkxztcc  2019-05-23T16:23:53.000Z
#
#                         EndTime                   geometry
# 22026  2019-10-23T17:18:06.000Z  POINT (-1.93400 54.44300)
# 22038  2019-10-26T16:26:20.000Z  POINT (-1.93700 53.44400)
# 22362  2019-10-23T17:11:15.000Z  POINT (-1.93300 53.44900)

# %%
gdf.drop_duplicates('Latitude')
# Out:
#                    Serial  Latitude  Longitude  \
# 22026  PI040298AD5I214048    54.443     -1.934
# 22032  PI040298AA4E057631    53.443     -1.934
# 22038  PI040298AD5J214359    53.444     -1.937
# 22362  PI040298AA4E057880    53.449     -1.933
#
#                                                  Type    SensorType  \
# 22026  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 22032  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 22038  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
# 22362  Thingful.Connectors.GROWSensors.AirTemperature  Flower Power
#
#                                  Code                 BeginTime  \
# 22026  Grow.Thingful.Sensors_98b4dscx  2019-05-23T16:11:17.000Z
# 22032  Grow.Thingful.Sensors_fb4x1a46  2019-05-23T16:14:00.000Z
# 22038  Grow.Thingful.Sensors_txegxh37  2019-05-23T15:10:46.000Z
# 22362  Grow.Thingful.Sensors_dwkxztcc  2019-05-23T16:23:53.000Z
#
#                         EndTime                   geometry
# 22026  2019-10-23T17:18:06.000Z  POINT (-1.93400 54.44300)
# 22032  2019-10-23T17:25:52.000Z  POINT (-1.93400 53.44300)
# 22038  2019-10-26T16:26:20.000Z  POINT (-1.93700 53.44400)
# 22362  2019-10-23T17:11:15.000Z  POINT (-1.93300 53.44900)
